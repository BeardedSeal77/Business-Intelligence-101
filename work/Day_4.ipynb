# %% [markdown]
# # Day 4 - Statistical Analysis

# %% [markdown]
# ## Exercise 1

# %%
age = c(13, 15, 16, 16, 19, 20, 20, 21, 22, 22, 25, 25, 25, 25, 30,
         33, 33, 35, 35, 35, 35, 36, 40, 45, 46, 52, 70)

age
# Out:
#  [1] 13 15 16 16 19 20 20 21 22 22 25 25 25 25 30 33 33 35 35 35 35 36 40 45 46
# [26] 52 70

# %%
mean_age <- mean(age)
min_age <- min(age)
max_age <- max(age)
median_age <- median(age)
lower_quantile_age <- quantile(age, 0.25)
upper_guantile_age <- quantile(age, 0.75)
iqr_age <- IQR(age)
mode_age <- mode(age)
summary(age)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   13.00   20.50   25.00   29.96   35.00   70.00

# %%
par(bg = "white")
boxplot(age, horizontal = TRUE, main = "Boxplot of Age")
# Out:
# Plot with title "Boxplot of Age"

# %%
par(bg = "white")
hist(age)
# Out:
# Plot with title "Histogram of age"

# %% [markdown]
# ## Exercise 2

# %%
age <- c(23, 23, 27, 27, 39, 41, 47, 49, 50, 52, 54, 54, 56, 57, 58, 58, 60, 61)
fat <- c(9.5, 26.5, 7.8, 17.8, 31.4, 25.9, 27.4, 27.2, 31.2, 34.6, 42.5, 28.8, 33.4, 30.2, 34.1, 32.9, 41.2, 35.7)

# %%
mean_age <- mean(age)
median_age <- median(age)
standard_deviation_age <- sd(age)

# %%
mean_age <- mean(fat)
median_age <- median(fat)
standard_deviation_age <- sd(fat)

# %%
par(bg = "white")
plot(age, fat, main = "Scatterplot between age and fat percentage")
# Out:
# Plot with title "Scatterplot between age and fat percentage"

# %%
par(bg = "white")
qqplot(age, fat, main = "Quartile-Quartile plot between age and fat percentage")
# Out:
# Plot with title "Quartile-Quartile plot between age and fat percentage"

# %%
similaraty_variables <- cor(age, fat)
similaraty_variables
# Out:
# [1] 0.8176188
